# %%
# 데이터 분석을 위한 작업에 있어서 유용한 도구들이 있는 패키지
# https://sophiesien.tistory.com/entry/Python-MLxtend-%EC%A3%BC%EC%9A%94-%EA%B8%B0%EB%8A%A5%EB%93%A4
# 참고할만한 기능을 소개하는 블로
import mlxtend
import numpy as np
import pandas as pd

# %%
data = np.array([
    ['우유', '기저귀', '쥬스'],
    ['양상추', '기저귀', '맥주'],
    ['우유', '양상추', '기저귀', '맥주'],
    ['양상추', '맥주']
])

# %% [markdown]
# ## Apriori 알고리즘

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(data).transform(data)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#      기저귀     맥주    양상추     우유     쥬스
# 0   True  False  False   True   True
# 1   True   True   True  False  False
# 2   True   True   True   True  False
# 3  False   True   True  False  False

# %%
# %%time
from mlxtend.frequent_patterns import apriori

apriori(df, min_support=0.5, use_colnames=True)
# Out:
# CPU times: user 14.5 ms, sys: 4.28 ms, total: 18.8 ms
# Wall time: 24.9 ms
#    support        itemsets
# 0     0.75           (기저귀)
# 1     0.75            (맥주)
# 2     0.75           (양상추)
# 3     0.50            (우유)
# 4     0.50       (맥주, 기저귀)
# 5     0.50      (양상추, 기저귀)
# 6     0.50       (우유, 기저귀)
# 7     0.75       (양상추, 맥주)
# 8     0.50  (양상추, 맥주, 기저귀)

# %% [markdown]
# ## FP-Growth 알고리즘

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(data).transform(data)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#      기저귀     맥주    양상추     우유     쥬스
# 0   True  False  False   True   True
# 1   True   True   True  False  False
# 2   True   True   True   True  False
# 3  False   True   True  False  False

# %%
# %%time
from mlxtend.frequent_patterns import fpgrowth

fpgrowth(df, min_support=0.5, use_colnames=True)
# Out:
# CPU times: user 2.59 ms, sys: 909 µs, total: 3.5 ms
# Wall time: 3.42 ms
#    support        itemsets
# 0     0.75           (기저귀)
# 1     0.50            (우유)
# 2     0.75           (양상추)
# 3     0.75            (맥주)
# 4     0.50       (맥주, 기저귀)
# 5     0.50      (양상추, 기저귀)
# 6     0.50  (양상추, 맥주, 기저귀)
# 7     0.50       (우유, 기저귀)
# 8     0.75       (양상추, 맥주)

# %% [markdown]
# ### Apriori에서 신뢰도나 향상도를 데이터프레임에서 확인하는 방법

# %%
from mlxtend.frequent_patterns import association_rules

# %%
association = fpgrowth(df, min_support=0.25, use_colnames=True)
association_rules(association, metric='confidence', min_threshold=0.5, support_only=False)
# Out:
#        antecedents     consequents  antecedent support  consequent support  \
# 0             (맥주)           (기저귀)                0.75                0.75
# 1            (기저귀)            (맥주)                0.75                0.75
# 2            (양상추)           (기저귀)                0.75                0.75
# 3            (기저귀)           (양상추)                0.75                0.75
# 4        (양상추, 맥주)           (기저귀)                0.75                0.75
# 5       (양상추, 기저귀)            (맥주)                0.50                0.75
# 6        (맥주, 기저귀)           (양상추)                0.50                0.75
# 7            (양상추)       (맥주, 기저귀)                0.75                0.50
# 8             (맥주)      (양상추, 기저귀)                0.75                0.50
# 9            (기저귀)       (양상추, 맥주)                0.75                0.75
# 10            (우유)           (기저귀)                0.50                0.75
# 11           (기저귀)            (우유)                0.75                0.50
# 12            (우유)            (맥주)                0.50                0.75
# 13            (우유)           (양상추)                0.50                0.75
# 14        (맥주, 우유)           (기저귀)                0.25                0.75
# 15       (맥주, 기저귀)            (우유)                0.50                0.50
# 16       (우유, 기저귀)            (맥주)                0.50                0.75
# 17            (우유)       (맥주, 기저귀)                0.50                0.50
# 18       (양상추, 우유)           (기저귀)                0.25                0.75
# 19      (양상추, 기저귀)            (우유)                0.50                0.50
# 20       (우유, 기저귀)           (양상추)                0.50                0.75
# 21            (우유)      (양상추, 기저귀)                0.50                0.50
# 22       (양상추, 우유)            (맥주)                0.25                0.75
# 23        (맥주, 우유)           (양상추)                0.25                0.75
# 24            (우유)       (양상추, 맥주)                0.50                0.75
# 25   (양상추, 맥주, 우유)           (기저귀)                0.25                0.75
# 26  (양상추, 맥주, 기저귀)            (우유)                0.50                0.50
# 27  (양상추, 우유, 기저귀)            (맥주)                0.25                0.75
# 28   (맥주, 우유, 기저귀)           (양상추)                0.25                0.75
# 29       (양상추, 우유)       (맥주, 기저귀)                0.25                0.50
# 30      (양상추, 기저귀)        (맥주, 우유)                0.50                0.25
# 31        (맥주, 우유)      (양상추, 기저귀)                0.25                0.50
# 32       (맥주, 기저귀)       (양상추, 우유)                0.50                0.25
# 33       (우유, 기저귀)       (양상추, 맥주)                0.50                0.75
# 34            (우유)  (양상추, 맥주, 기저귀)                0.50                0.50
# 35            (쥬스)            (우유)                0.25                0.50
# 36            (우유)            (쥬스)                0.50                0.25
# 37            (쥬스)           (기저귀)                0.25                0.75
# 38        (쥬스, 우유)           (기저귀)                0.25                0.75
# 39       (쥬스, 기저귀)            (우유)                0.25                0.50
# 40       (우유, 기저귀)            (쥬스)                0.50                0.25
# 41            (쥬스)       (우유, 기저귀)                0.25                0.50
# 42            (우유)       (쥬스, 기저귀)                0.50                0.25
# 43           (양상추)            (맥주)                0.75                0.75
# 44            (맥주)           (양상추)                0.75                0.75
#
#     support  confidence      lift  leverage  conviction
# 0      0.50    0.666667  0.888889   -0.0625        0.75
# 1      0.50    0.666667  0.888889   -0.0625        0.75
# 2      0.50    0.666667  0.888889   -0.0625        0.75
# 3      0.50    0.666667  0.888889   -0.0625        0.75
# 4      0.50    0.666667  0.888889   -0.0625        0.75
# 5      0.50    1.000000  1.333333    0.1250         inf
# 6      0.50    1.000000  1.333333    0.1250         inf
# 7      0.50    0.666667  1.333333    0.1250        1.50
# 8      0.50    0.666667  1.333333    0.1250        1.50
# 9      0.50    0.666667  0.888889   -0.0625        0.75
# 10     0.50    1.000000  1.333333    0.1250         inf
# 11     0.50    0.666667  1.333333    0.1250        1.50
# 12     0.25    0.500000  0.666667   -0.1250        0.50
# 13     0.25    0.500000  0.666667   -0.1250        0.50
# 14     0.25    1.000000  1.333333    0.0625         inf
# 15     0.25    0.500000  1.000000    0.0000        1.00
# 16     0.25    0.500000  0.666667   -0.1250        0.50
# 17     0.25    0.500000  1.000000    0.0000        1.00
# 18     0.25    1.000000  1.333333    0.0625         inf
# 19     0.25    0.500000  1.000000    0.0000        1.00
# 20     0.25    0.500000  0.666667   -0.1250        0.50
# 21     0.25    0.500000  1.000000    0.0000        1.00
# 22     0.25    1.000000  1.333333    0.0625         inf
# 23     0.25    1.000000  1.333333    0.0625         inf
# 24     0.25    0.500000  0.666667   -0.1250        0.50
# 25     0.25    1.000000  1.333333    0.0625         inf
# 26     0.25    0.500000  1.000000    0.0000        1.00
# 27     0.25    1.000000  1.333333    0.0625         inf
# 28     0.25    1.000000  1.333333    0.0625         inf
# 29     0.25    1.000000  2.000000    0.1250         inf
# 30     0.25    0.500000  2.000000    0.1250        1.50
# 31     0.25    1.000000  2.000000    0.1250         inf
# 32     0.25    0.500000  2.000000    0.1250        1.50
# 33     0.25    0.500000  0.666667   -0.1250        0.50
# 34     0.25    0.500000  1.000000    0.0000        1.00
# 35     0.25    1.000000  2.000000    0.1250         inf
# 36     0.25    0.500000  2.000000    0.1250        1.50
# 37     0.25    1.000000  1.333333    0.0625         inf
# 38     0.25    1.000000  1.333333    0.0625         inf
# 39     0.25    1.000000  2.000000    0.1250         inf
# 40     0.25    0.500000  2.000000    0.1250        1.50
# 41     0.25    1.000000  2.000000    0.1250         inf
# 42     0.25    0.500000  2.000000    0.1250        1.50
# 43     0.75    1.000000  1.333333    0.1875         inf
# 44     0.75    1.000000  1.333333    0.1875         inf

# %% [markdown]
# - 룰 기반의 알고리즘
# - 메모리 사용이 너무 크다
# - 생성된 규칙이 너무 많아 적용하기 어렵다
# - Apriori는 데이터 셋을 처음 받았을 때 의미 찾는 형식의 EDA 과정에서 사용 가능
# - 실제로는 협업, 컨텐츠, 딥러닝 기반 알고리즘이 현업에서 사용된다.

# %% [markdown]
# ### 강의 중 질문 : 신규 고객에게는 빈도가 제일 높거나 지지도가 제일 높은 상품을 사라고 권하면 되지 않을까요?
# - 신규 고객, 기존 고객, 충성 고객 등 타겟 집단을 나눠야 한다.
# - 도메인 따라서 데이터 확인 후 진행
